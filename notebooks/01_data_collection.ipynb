# %%
from pathlib import Path
import sys

# Detect environment
if 'google.colab' in sys.modules:
    print("Running in Google Colab environment.")
    repo_root = Path('/content/SENTIMENT-ANALYSIS-TOOL')
else:
    print("Running in local environment.")
    repo_root = Path().resolve().parent  # Go up one level to project root

# Define raw and processed data paths
raw_data_path = repo_root / "Data" / "Raw Data"
processed_data_path = repo_root / "Data" / "Processed Data"

print(f"Raw data path: {raw_data_path}")
print(f"Processed data path: {processed_data_path}")
# Out:
# Running in local environment.
# Raw data path: C:\Users\LENOVO\OneDrive\Documents\Strath\Masters\sentiment-analysis-tool\Data\Raw Data
# Processed data path: C:\Users\LENOVO\OneDrive\Documents\Strath\Masters\sentiment-analysis-tool\Data\Processed Data
